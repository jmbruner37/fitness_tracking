# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
filepath = 'ac_garmin.csv'
garmin_df = pd.read_csv(filepath)
filepath2 ='ac_torben.csv'
torben_df = pd.read_csv(filepath2)

# %%
#drop the null values 
garmin_df.dropna(inplace=True)

# %%
garmin_df.head()
# Out:
#   Activity Type                 Date  Favorite                    Title  \
# 0       Running  2020-10-29 14:50:02     False      Park County Running
# 1       Running  2020-10-29 13:34:15     False      Park County Running
# 2       Running  2020-10-27 10:34:34     False     Grand County Running
# 3       Running  2020-10-26 15:12:37     False  San Juan County Running
# 4       Running  2020-10-25 11:27:04     False  Garfield County Running
#
#    Distance Calories      Time Avg HR Max HR Aerobic TE  ... Bottom Time  \
# 0      1.02      183  00:39:41     96    127          1  ...    00:00:00
# 1      0.72      137  00:31:13     91    117        0.6  ...    00:00:00
# 2      2.01      224  00:35:41    110    138        1.7  ...    00:00:00
# 3      1.89      259  00:50:17    104    129        0.9  ...    00:00:00
# 4      8.43     1251  03:01:06    130    178        3.7  ...    00:00:00
#
#   Min Temp Surface Interval Decompression    Best Lap Time Number of Laps  \
# ...

# %%
garmin_df.columns
# Out:
# Index(['Activity Type', 'Date', 'Favorite', 'Title', 'Distance', 'Calories',
#        'Time', 'Avg HR', 'Max HR', 'Aerobic TE', 'Avg Run Cadence',
#        'Max Run Cadence', 'Avg Pace', 'Best Pace', 'Elev Gain', 'Elev Loss',
#        'Avg Stride Length', 'Avg Vertical Ratio', 'Avg Vertical Oscillation',
#        'Avg Run Cadence.1', 'Training Stress ScoreÂ®', 'Grit', 'Flow',
#        'Climb Time', 'Bottom Time', 'Min Temp', 'Surface Interval',
#        'Decompression', 'Best Lap Time', 'Number of Laps', 'Max Temp',
#        'Avg Resp', 'Min Resp', 'Max Resp'],
#       dtype='object')

# %%
garmin_df = garmin_df[['Activity Type','Date','Distance','Calories','Time','Avg HR','Max HR','Aerobic TE','Avg Run Cadence','Max Run Cadence','Avg Pace','Best Pace','Elev Loss','Avg Stride Length','Climb Time','Min Temp','Best Lap Time','Number of Laps']]

# %%
garmin_df.head()
# Out:
#   Activity Type                 Date  Distance Calories      Time Avg HR  \
# 0       Running  2020-10-29 14:50:02      1.02      183  00:39:41     96
# 1       Running  2020-10-29 13:34:15      0.72      137  00:31:13     91
# 2       Running  2020-10-27 10:34:34      2.01      224  00:35:41    110
# 3       Running  2020-10-26 15:12:37      1.89      259  00:50:17    104
# 4       Running  2020-10-25 11:27:04      8.43     1251  03:01:06    130
#
#   Max HR Aerobic TE Avg Run Cadence Max Run Cadence             Avg Pace  \
# 0    127          1              49             158  1900-01-01 15:03:00
# 1    117        0.6              40             162  1900-01-01 19:33:00
# 2    138        1.7              91             250             17:46:00
# 3    129        0.9              71             225  1900-01-01 02:38:00
# 4    178        3.7              97             250             21:30:00
#
#   Best Pace Elev Loss  Avg Stride Length           Climb Time  Min Temp  \
# ...

# %%
connection_string = 
engine = create_engine(f'postgresql://{connection_string}'')
